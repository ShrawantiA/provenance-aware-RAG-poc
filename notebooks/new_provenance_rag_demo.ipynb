# %% [markdown]
# # Provenance RAG Demo
#
# Minimal notebook for provenance-aware RAG proof-of-concept.
#
# Contains a simple print cell so GitHub can render this as a notebook.

# %%
print('Hello — provenance RAG demo notebook is valid JSON!')
